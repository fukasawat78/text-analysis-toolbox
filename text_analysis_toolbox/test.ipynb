# %% [markdown]
# ## Demo

# %% [markdown]
# ## Setup & Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook as tqdm
import japanize_matplotlib
from embedding_and_clustering import *

from text_analysis_toolbox import TextAnalysisToolBox

# %% [markdown]
# ## データ読み込み & 前処理

# %%
import yaml
with open("./config.yml") as yml:
    configs = yaml.load(yml)

df = pd.read_csv("../data/dataset.csv", encoding="utf-8-sig", index_col=0)
df = df[:500]

# Instance
tat = TextAnalysisToolBox()

# Preprocessing
df = tat.transform(df)
# Out:
# 500it [00:10, 44.28it/s]

# %% [markdown]
# ## W2V Embeddings and Clustering

# %%
umap_res, words, labels = tat.embedding_and_clustering_scatter(df, configs)

# %% [markdown]
# ## LDA WordCloud

# %%
lda_model = tat.lda_wordcloud(df)
# Out:
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-b4aa345d5eec> in <module>()
# ----> 1 lda_model = tdd.lda_wordcloud(df)
#
# ~/GitHub/text-data-dashboard/text_data_dashboard/text_data_dashboard.py in lda_wordcloud(self, df)
#      76         lda_model = gensim.models.ldamodel.LdaModel(corpus=corpus, id2word=dictionary, num_topics=8, random_state=0)
#      77
# ---> 78         get_wordcloud(lda_model)
#      79
#      80         return lda_model
#
# NameError: name 'get_wordcloud' is not defined
