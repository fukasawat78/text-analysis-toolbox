# %% [markdown]
# ## Demo

# %% [markdown]
# ## Setup & Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from tqdm import tqdm_notebook as tqdm
import japanize_matplotlib
from text_analysis_toolbox import TextAnalysisToolBox

# %% [markdown]
# ## データ読み込み & 前処理

# %%
import yaml
with open("./config.yml") as yml:
    configs = yaml.load(yml)

df_raw = pd.read_csv("../data/dataset.csv", encoding="utf-8-sig", index_col=0)
df_raw = df_raw[:500]

# Instance
tat = TextAnalysisToolBox()

# Preprocessing
df = tat.transform(df_raw)
# Out:
# 500it [00:05, 91.27it/s]

# %% [markdown]
# ## W2V Embeddings and Clustering

# %%
umap_res, words, labels = tat.embedding_and_clustering_scatter(df, configs)
# Out:
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))

# %% [markdown]
# ## LDA WordCloud

# %%
lda_model = tat.lda_wordcloud(df)
# Out:
# HBox(children=(IntProgress(value=0, max=500), HTML(value='')))
